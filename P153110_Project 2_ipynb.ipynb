# %% [markdown]
# # **INTRODUCTION**
#
# The dataset is obtained from the pharmaceutical company "Pharmaniaga" The dataset can be downloaded from [data](https://docs.google.com/spreadsheets/d/1LW5YkRKvbztMtTUK5NuNGZ_vclnktxIz/edit?usp=drive_link&ouid=117138986410645649344&rtpof=true&sd=trueURL) for reproducibility.It provides information on transaction sales data form year 2021 to 2024 including informations such as product details and sales value
#
# The purpose of this project is to analyze the dataset containing sales data from the "Novel Department" in "Pharmaniaga" from 2021 till 2024 to provide actionable insights into sales performance, geographic trends and customer behaviour to enable the department or business to make data-driven decisions to optimize sales stratey and maximize revenue.

# %%
# !pip install pandas openpyxl
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.11/dist-packages (3.1.5)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.11/dist-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd
import pandas as pd

# Replace with your actual raw URL
file_url = "https://docs.google.com/spreadsheets/d/1LW5YkRKvbztMtTUK5NuNGZ_vclnktxIz/edit?usp=drive_link&ouid=117138986410645649344&rtpof=true&sd=true"
#  The URL needs to be the direct link to the CSV or Excel file, not the Google Sheets edit URL.  You'll need to download the file and provide the correct path or find the raw CSV URL.

# or for Excel files:
# df = pd.read_excel(file_url)

# %%
file_name = "Novel_Department_Master.xlsx"
df = pd.read_excel(file_name)
#Display the dataframe
print(df.head())
# Out:
#    WH   Cust Group    Month  Year QTD     Brand            Item  \
# 0  E1  (d) Private  January  2021  Q1   AFTAMED  01.1415.29.891
# 1  E1  (d) Private  January  2021  Q1   AFTAMED  01.1415.30.891
# 2  E1  (d) Private  January  2021  Q1  GENGIGEL  01.1415.02.892
# 3  E1  (d) Private  January  2021  Q1  GENGIGEL  01.1415.02.892
# 4  E1  (d) Private  January  2021  Q1  GENGIGEL  01.1415.03.892
#
#                                      Description  Customer Acc No  \
# 0                AFTAMED GEL CLASSIC.TUBE OF 8ML          16026.0
# 1                 AFTAMED JUNIOR GEL.TUBE OF 8ML          16026.0
# 2                      GENGIGEL GEL.TUBE OF 20ML          62071.0
# 3                      GENGIGEL GEL.TUBE OF 20ML          62071.0
# 4  GENGIGEL  HYDROGEL MOUTHRINSE.BOTTLE OF 150ML          62071.0
#
#                     Customer Name  ...    DOCNO Area sales PS 2024  \
# 0      51 AVENUE PHARMACY SDN BHD  ...  4791137        AS1    GCE1
# 1      51 AVENUE PHARMACY SDN BHD  ...  4791137        AS1    GCE1
# 2  AA PHARMACY HEALTHCARE SDN BHD  ...  4782739        AS1    KAC1
# 3  AA PHARMACY HEALTHCARE SDN BHD  ...  4800836        AS1    KAC1
# 4  AA PHARMACY HEALTHCARE SDN BHD  ...  4813177        AS1    KAC1
#
#              SalesRep Name       Supplier Name QTY1 + QTY2) SUM(MISALES)  \
# 0  HEMAL GEETHENDRA MALANI  BIOPLAX ITALIA SRL         25.0        450.0
# 1  HEMAL GEETHENDRA MALANI  BIOPLAX ITALIA SRL          5.0         90.0
# 2       SHARON TEO XUE YAN       RICERFAMA SRL        100.0       2600.0
# 3       SHARON TEO XUE YAN       RICERFAMA SRL        150.0       3900.0
# 4       SHARON TEO XUE YAN       RICERFAMA SRL         50.0       1250.0
#
#         Town  POSCODE     State
# 0     KAJANG    43000  SELANGOR
# 1     KAJANG    43000  SELANGOR
# 2  SHAH ALAM    40150  SELANGOR
# 3  SHAH ALAM    40150  SELANGOR
# 4  SHAH ALAM    40150  SELANGOR
#
# [5 rows x 23 columns]

# %%
#Description of the dataset
print(df.describe())
print(df.columns)
# Out:
#                Year  Customer Acc No  QTY1 + QTY2)   SUM(MISALES)
# count  72829.000000     72772.000000  72788.000000   72829.000000
# mean    2022.639937     32565.771547     29.855072     977.456999
# std        1.116584     25142.505513     65.405190    2174.815203
# min     2021.000000      1004.000000   -550.000000  -13750.000000
# 25%     2022.000000      6572.000000      5.000000     240.000000
# 50%     2023.000000     28803.000000     12.000000     498.800000
# 75%     2024.000000     62460.000000     30.000000    1080.000000
# max     2024.000000     97000.000000   5000.000000  170000.000000
# Index(['WH', 'Cust Group', 'Month', 'Year', 'QTD', 'Brand', 'Item',
#        'Description', 'Customer Acc No', 'Customer Name', 'Sector', 'KA/NKA',
#        'PV/NPV', 'DOCNO', 'Area sales', 'PS 2024', 'SalesRep Name',
#        'Supplier Name', 'QTY1 + QTY2)', 'SUM(MISALES)', 'Town', 'POSCODE',
#        'State'],
#       dtype='object')

# %% [markdown]
# The dataset consists of columns such as:
#
# 1.   WH: Warehouse identifier
# 2.   Cust Group: Customer group classification
# 3. Month: Month of the transaction
# 4. Year: Year of the transaction
# 5. QTD: Quarter to date indicator
# 6. Brand: Product brand
# 7. Item: Item code
# 8. Description: Item description
# 9. Customer Acc No: Customer account number
# 10. Customer Name: Name of the customer
# 11. Sector: Customer sector classification
# 12. KA/NKA: Key account (KA) or non-key account(NKA) status
# 13. PV/NPV: Product value classification
# 14. DOCNO: Document number
# 15. Area sales: Sales area identifier
# 16. PS 2024:Performance segment for 2024
# 17. SalesRep Name: Name of the sales representative
# 18. Supplier Name: Name of the product supplier
# 19. QTY1 + QTY2): Combined quantity of products
# 20. SUM(MISALES): Total sales amount
# 21. Town: Customer's town
# 22. POSCODE: Postal code
# 23. State: State of the customer

# %% [markdown]
# # **PROBLEM STATEMENT**
#
# The company is on financial recovery after few setbacks due to multiple factors incluidng he Covid-19 pandemic. In its pursuit of sustainable growth, the company aims to to optimize its sales performance and understand key drives behind revenue growth by analysing historical sales data from year 2021 till 2024. The Novel department is one of the department that shows potential in bringing profit to the company with its lineup of new and experienced team members. As a data scientist, I could contribute by identifying overall sales trends, evaluate product and brand performance, analyse customer behaviour and regional sales distribution. These insights will help shape strategic decision making around marketing, product and regional growth.

# %% [markdown]
# DATA *CLEANING*

# %%
#Check and display duplicated rows
df.duplicated().sum()
duplicated_rows = df[df.duplicated()]
print(f"Number of Duplicate Rows: {duplicated_rows}")
# Out:
# Number of Duplicate Rows:        WH   Cust Group    Month  Year QTD     Brand            Item  \
# 215    E1  (d) Private  January  2021  Q1  GENGIGEL  01.1415.01.892
# 216    E1  (d) Private  January  2021  Q1  GENGIGEL  01.1415.02.892
# 217    E1  (d) Private  January  2021  Q1  GENGIGEL  01.1415.01.892
# 218    E1  (d) Private  January  2021  Q1  GENGIGEL  01.1415.02.892
# 318    E1  (d) Private  January  2021  Q1  GENGIGEL  01.1415.20.892
# ...    ..          ...      ...   ...  ..       ...             ...
# 63399  E1  (d) Private     July  2024  Q3  GENGIGEL  01.1415.02.892
# 64023  E1  (d) Private   August  2024  Q3   AFTAMED  01.1415.29.891
# 64025  E1  (d) Private   August  2024  Q3   AFTAMED  01.1415.29.891
# 64062  E1  (d) Private   August  2024  Q3   AFTAMED  01.1415.19.891
# 64475  E1  (d) Private   August  2024  Q3   AFTAMED  01.1415.19.891
#
#                               Description  Customer Acc No  \
# 215    GENGIGEL GEL 1G.BOX OF 100 SACHETS          33850.0
# 216             GENGIGEL GEL.TUBE OF 20ML          33850.0
# 217    GENGIGEL GEL 1G.BOX OF 100 SACHETS          33850.0
# 218             GENGIGEL GEL.TUBE OF 20ML          33850.0
# 318         GENGIGEL SPRAY.BOTTLE OF 20ML           8758.0
# ...                                   ...              ...
# 63399           GENGIGEL GEL.TUBE OF 20ML           3557.0
# 64023     AFTAMED GEL CLASSIC.TUBE OF 8ML           2426.0
# 64025     AFTAMED GEL CLASSIC.TUBE OF 8ML           2426.0
# 64062        AFTAMED SPRAY.BOTTLE OF 20ML          72287.0
# 64475        AFTAMED SPRAY.BOTTLE OF 20ML          65508.0
#
#                                       Customer Name  ...    DOCNO Area sales  \
# 215        FARMASI PARKCITY (AVELON HEALTHCARE S/B)  ...  4780948        AS3
# 216        FARMASI PARKCITY (AVELON HEALTHCARE S/B)  ...  4780948        AS3
# 217        FARMASI PARKCITY (AVELON HEALTHCARE S/B)  ...  4780948        AS3
# 218        FARMASI PARKCITY (AVELON HEALTHCARE S/B)  ...  4780948        AS3
# 318                                   KLINIK AMPANG  ...  4793976        AS3
# ...                                             ...  ...      ...        ...
# 63399              SIBU SPECIALIST HOSPITAL SDN BHD  ...      NaN        AS1
# 64023                          FARMASI RS SDN. BHD.  ...  6708812        AS2
# 64025                          FARMASI RS SDN. BHD.  ...  6708812        AS2
# 64062  KLINIK AJWA (OWNED BY AJWA GRANDEUR SDN BHD)  ...  6707245        AS2
# 64475                                  KLINIK DIZAD  ...  6720965        AS3
#
#       PS 2024                    SalesRep Name       Supplier Name  \
# 215      GCE5                      FARAH HANNI       RICERFAMA SRL
# 216      GCE5                      FARAH HANNI       RICERFAMA SRL
# 217      GCE5                      FARAH HANNI       RICERFAMA SRL
# 218      GCE5                      FARAH HANNI       RICERFAMA SRL
# 318      GCE5                      FARAH HANNI       RICERFAMA SRL
# ...       ...                              ...                 ...
# 63399    GEM1                    MOK SIEW FANG      RICERFARMA SRL
# 64023    GNN1  GEETAN KUMAR A/L NARAYANAN SAMY  BIOPLAX ITALIA SRL
# 64025    GNN1  GEETAN KUMAR A/L NARAYANAN SAMY  BIOPLAX ITALIA SRL
# 64062    GCE4                     QUEK YAN YEE  BIOPLAX ITALIA SRL
# 64475    GSN1         NOR DALILAH BT ABD GHANI  BIOPLAX ITALIA SRL
#
#       QTY1 + QTY2) SUM(MISALES)          Town  POSCODE     State
# 215           10.0       1350.0        KEPONG    52100    WP(KL)
# 216          100.0       2600.0        KEPONG    52100    WP(KL)
# 217           10.0       1350.0        KEPONG    52100    WP(KL)
# 218          100.0       2600.0        KEPONG    52100    WP(KL)
# 318           25.0        675.0  KUALA LUMPUR    53300    WP(KL)
# ...            ...          ...           ...      ...       ...
# 63399          1.0         33.0       SARAWAK    96000   SARAWAK
# 64023          5.0        110.0          IPOH    30100     PERAK
# 64025          5.0        110.0          IPOH    30100     PERAK
# 64062         25.0        625.0   PUNCAK ALAM    42300  SELANGOR
# 64475         25.0        625.0        TAMPOI    81200     JOHOR
#
# [1638 rows x 23 columns]

# %%
# Pass a list of columns to drop to the 'columns' argument
df.drop(columns=['WH', 'QTD', 'Item','Customer Acc No', 'Customer Name', 'KA/NKA', 'PV/NPV', 'DOCNO', 'Area sales', 'Town','PS 2024', 'SalesRep Name', 'Supplier Name', 'POSCODE'], inplace=True)

# %%
#The remaining duplicate rows are retained as required for the analysis
print(df.columns)
# Out:
# Index(['Cust Group', 'Month', 'Year', 'Brand', 'Description', 'Sector',
#        'QTY1 + QTY2)', 'SUM(MISALES)', 'State'],
#       dtype='object')

# %%
# Verify Data Types
print("Column Data Types:")
print(df.dtypes)
# Out:
# Column Data Types:
# Cust Group       object
# Month            object
# Year              int64
# Brand            object
# Description      object
# Sector           object
# QTY1 + QTY2)    float64
# SUM(MISALES)    float64
# State            object
# dtype: object

# %%
#Standardize Columns to a consistent format
df.rename(columns={'SUM(MISALES)': 'Total_sales'}, inplace=True)

# %%
df.columns = (
    df.columns.str.strip()  #remove trailing spaces
                .str.lower() #change to lowercase
                .str.replace(' ','_') #replace spaces with underscores
)
print(df.columns)
# Out:
# Index(['cust_group', 'month', 'year', 'brand', 'description', 'sector',
#        'qty1_+_qty2)', 'total_sales', 'state'],
#       dtype='object')

# %%
df.rename(columns={'qty1_+_qty2)': 'quantity'}, inplace=True)
print(df.columns)
# Out:
# Index(['cust_group', 'month', 'year', 'brand', 'description', 'sector',
#        'quantity', 'total_sales', 'state'],
#       dtype='object')

# %% [markdown]
# Handling missing values
#
# Based on my purpose of analysis and the nature of the data, the missing values are replaced with zero instead of using mean or median because of several reason as below:
# 1. To reflect the reality of no sales where transaction with a missing quantity could mean no items purchased
# 2. As the dataset involves various products and regions, replacing with mean or median introduces artificial value that distort the analysis. It could skew the sales trends and increase bias. For example, region A may have high sales and region B low sales, by replacing misisng values in region with a value could lead to inappropriate comparisons across product and regions and doesnt preserve its unique characteristics.
# 3. Preserves aggregated analysis accuracy as it is crucial for the analysis that will be done

# %%
#Check for missing values
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# cust_group      0
# month           0
# year            0
# brand           0
# description     0
# sector          0
# quantity       41
# total_sales     0
# state           0
# dtype: int64

# %%
#there are 41 missing values at column "Quantity"
#the missing values are filled with zero to ensure data integrity while maintaining all other data points for analysis
df['quantity'] = df['quantity'].fillna(0)
print("Missing values in 'quantity' column have been replaced with 0. ")
# Out:
# Missing values in 'quantity' column have been replaced with 0.

# %%
#remove rows with negative or zero values in 'Quantity" and SUM(MISALES)
df = df[(df['quantity'] > 0) & (df['total_sales'] > 0)]
print(f"Number of rows after removing negative and zero values: {df.shape[0]}")
# Out:
# Number of rows after removing negative and zero values: 70273

# %% [markdown]
# Handling Outliers
#
# One of the methods to handle outliers is using the IQR. To decide on whether a data is an outlier, we can observe the equation:
#
# Upper Fence=Q3+1.5(IQR)
# Lower Fence=Q1−1.5(IQR)
#
# Any values which are above the upper fence and below the lower fence, can be classified as outliers. However based on the objective of each analysis, outliers are retained because of its importance in representing the core information required which may drive strategic focus. However, the outlier is handled separately in the analysis of Percentage Growth in Sales for comparison on its impact on growth rates which will be discussed later below

# %%
# Create the box plot
plt.figure(figsize=(15, 8))
sns.boxplot(data=df[['total_sales', 'quantity']]) # Fixed: Removed extra indent
plt.title('Box Plot of Total Sales and Quantity')
plt.ylabel('Value')
plt.yscale('log')  # Apply logarithmic scale to y-axis
plt.show()

# %%
#Extract and standardize the unique values for the specified columns
columns_to_standardize = ['cust_group', 'month', 'brand', 'description', 'state']
standardised_values = {}

for col in columns_to_standardize:
  unique_values = df[col].unique()
  standardised_values[col] = unique_values
  df[col] = df[col].str.replace(r'\s+',' ', regex=True)
  df[col] = df[col].str.title()

for col, unique_values in standardised_values.items():
    print(f"Unique values in '{col}':")
    print(unique_values)
    print("\n")
# Out:
# Unique values in 'cust_group':
# ['(d) Private' '(c) Institution' '(a) MOH Sales' 'UNIDENTIFIED']
#
#
# Unique values in 'month':
# ['January' 'February ' 'March' 'April' 'May' 'June' 'July' 'August'
#  'September' 'October' 'November' 'December' 'OCTOBER' 'February']
#
#
# Unique values in 'brand':
# ['AFTAMED' 'GENGIGEL' 'V-HYAL' 'SFN10' 'ATOPSHIELD' 'ALLERSTOP' '3M'
#  'ONTREX' 'PEROZIN' 'Aftamed' 'Allerstop' 'Atopshield' 'Perozin'
#  'BABY NADIF' 'DENTAL STONE' 'DENTAL PLASTER' 'IMINOX' 'DENTSPLY']
#
#
# Unique values in 'description':
# ['AFTAMED GEL CLASSIC.TUBE OF 8ML' 'AFTAMED JUNIOR GEL.TUBE OF 8ML'
#  'GENGIGEL GEL.TUBE OF 20ML'
#  'GENGIGEL  HYDROGEL MOUTHRINSE.BOTTLE OF 150ML'
#  'AFTAMED SPRAY.BOTTLE OF 20ML' 'GENGIGEL SPRAY.BOTTLE OF 20ML'
#  'VAGINAL HYAL GEL.TUBE OF 30G' 'SFN10 NAIL MYCOSIS.TUBE OF 3.3ML'
#  'ATOPSHIELD LOTION.TUBE OF 100ML' 'ALLERSTOP SPRAY 30ML.BOTTLE OF 30ML'
#  'GENGIGEL GEL 1G.BOX OF 100 SACHETS' 'ATOPSHIELD CREAM.TUBE OF 40ML'
#  'DUR5 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE S'
#  'DUR6 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE S'
#  'DUR7 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE S'
#  'DLL5 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE S'
#  'DUL5 S/S CROWNS PRIMARY MOLAR 2EA..BOX OF 2 CROWNS ONE'
#  'DUL6 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE S'
#  'DLL4 S/S CROWNS PRIMARY MOLAR.BOX OF 2 CROWNS ONE SIZE'
#  'DLL2 S/S CROWNS PRIMARY MOLAR 2EA...BOX OF 2 CROWNS ONE'
#  'DLR4 S/S CROWNS PRIMARY MOLAR.BOX OF 2 CROWNS ONE SIZE'
#  'DUL2 S/S CROWNS PRIMARY MOLAR.BOX OF 2 CROWNS ONE SIZE'
#  'DUL4 S/S CROWNS PRIMARY MOLAR.BOX OF 2 CROWNS ONE SIZE'
#  'DUR3 S/S CROWNS PRIMARY MOLAR.BOX OF 2 CROWNS ONE SIZE'
#  'DUR4 S/S CROWNS PRIMARY MOLAR.BOX OF 2 CROWNS ONE SIZE'
#  'DUL3 S/S CROWNS PRIMARY MOLAR.BOX OF 2 CROWNS ONE SIZE'
#  'DLL3 S/S CROWNS PRIMARY MOLAR.BOX OF 2 CROWNS'
#  'DLR3 S/S CROWNS PRIMARY MOLAR.BOX OF 2 CROWNS'
#  'EUL3 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE S'
#  'EUL4 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE S'
#  'EUL5 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE S'
#  'ELL3 S/S CROWNS PRIMARY MOLAR.BOX OF 2 CROWNS ONE SIZE'
#  'ELR3 S/S CROWNS PRIMARY MOLAR 2EA...BOX OF 2 CROWNS OF'
#  'ELR7 S/S CROWNS PRIMARY MOLAR.BOX OF 2 CROWNS ONE SIZE'
#  'EUR7 S/S CROWNS PRIMARY MOLAR.BOX OF 2 CROWNS ONE SIZE'
#  '6LL7 S/S CROWN PERMANENT MOLAR.BOX OF 5 CROWNS ONE SIZE'
#  '6LL6 S/S CROWN PERMANENT MOLAR.BOX OF 5 CROWNS ONE SIZE'
#  '6LR6 S/S CROWN PERMANENT MOLAR.BOX OF 5 CROWNS ONE SIZE'
#  '6LR5 S/S CROWN PERMANENT MOLAR.BOX OF 5 CROWNS ONE SIZE'
#  '6UR4 S/S CROWN PERMANENT MOLAR.BOX OF 5 CROWNS'
#  '6UR5 S/S CROWN PERMANENT MOLAR.BOX OF 5 CROWNS'
#  'AFTAMED GEL CLASSIC 1ML.BOX OF 100 SACHETS'
#  '36975 EXPRESS XT REG BODY.BOX OF KIT'
#  'GENGIGEL PROF FLUID.BOTTLE OF 500ML'
#  'GENGIGEL PROF SYRINGES.PACK OF 4X1ML SYRINGES'
#  'DLR7 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE S'
#  'DUR2 S/S CROWNS PRIMARY MOLAR.BOX OF 2 CROWNS ONE SIZE'
#  'ELL6 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE S'
#  'EUR4 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE S'
#  'ELR6 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE S'
#  'ELL7 S/S CROWNS PRIMARY MOLAR.BOX OF 2 CROWNS ONE SIZE'
#  '3525A RELYX LUTING 2 CLICKER.BOX OF KIT'
#  '41282 SINGLE BOND UNIVERSAL ADHESIVE.BOTTLE OF 5ML'
#  '12647 CLINPRO SEALANT SYRINGE.BOX OF SYRINGE'
#  '1470A3 FILTEK Z250XT.SYRINGE OF 3G'
#  '8100A3 FILTEK P60 A3.BOX OF 4G SYRINGE'
#  '1470A2 FILTEK Z250XT.BOX OF 3G SYRINGE'
#  '61104 KETAC UNIVERSAL HM KIT A3.BOX OF KIT'
#  '12646 CLINPRO SEALANT SYRINGE.BOX OF LOCAL KIT'
#  '801202 DELUXE CURVED CROWN SCI.BOX OF AN EQUIPMENT'
#  'PO96 S/S CROWNS - PERMANENT MO.BOX OF KIT'
#  '4868A3 FILTEK ONE SYR BULK 4G.SYRINGE OF 4G'
#  '7423 SCOTCHBOND ETCHANT.BOTTLE OF 9ML'
#  'EUR3 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE S'
#  'EUR5 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE S'
#  'EUR6 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE S'
#  '31798 SOFT MONOPHASE.BOX OF KIT' '56878 RELY X U200 A2.BOX OF KIT'
#  '7018A2B FILTEK Z350XT.SYRINGE OF 4G'
#  '7018A35B FILTEK Z350XT.SYRINGE OF 4G'
#  '7018A3B FILTEK Z350XT.SYRINGE OF 4G'
#  '77919 PENTA MIXING TIPS (30).BOX OF TIPS'
#  '46953 PROTEMP 4 INTRO KIT A2.BOX OF KIT'
#  '56877 RELY X U200 TR.BOX OF KIT'
#  '7018A2E FILTEK Z350XT A2E.SYRINGE OF 4G'
#  '7018A3E FILTEK Z350XT A3E.SYRINGE OF 4G'
#  '7018B2E FILTEK Z350XT B2E.SYRINGE OF 4G'
#  '7032A2 SUP FLOW SYR 2G.KIT OF 2 SYRINGE'
#  '7032A3 SUP FLOW 2 SYR/KT.SYRINGE OF 2G'
#  '71210 PENTA ELASTOMER SYRINGE.BOX OF KIT'
#  'EUL7 S/S CROWNS PRIMARY MOLAR.BOX OF 2 CROWNS ONE SIZE'
#  '30600 POLYETHER ADHESIVE.BOTTLE OF 17ML'
#  '914003 PEDO STRIP CROWN ULC3.BOX OF 5 CROWNS ONE SIZE'
#  '914012 PEDO STRIP CROWN URC2.BOX OF 5 CROWNS ONE SIZE'
#  '914013 PEDO STRIP CROWN URC3.BOX OF 5 CROWNS ONE SIZE'
#  '914023 PEDO STRIP CROWN ULL3.BOX OF 5 CROWNS ONE SIZE'
#  '914032 PEDO STRIP CROWN URL2.BOX OF 5 CROWNS ONE SIZE'
#  '914033 PEDO STRIP CROWN URL3.BOX OF 5 CROWNS ONE SIZE'
#  '915100 PEDO STRIP CROWNS KIT.BOX OF KIT'
#  '12246L CLINPRO WHITE VARNISH KIT,MELON.BOX OF 100 PACKS'
#  'DUL7 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE S'
#  '51202 ADPER SINGLE BOND 2.VIAL OF 6 ML'
#  '15141 UBISTESIN-F.TIN OF 50 CARTRIDGE'
#  'DLL6 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE S'
#  'DLL7 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE S'
#  'DLR2 S/S CROWNS PRIMARY MOLAR.BOX OF 2 CROWNS ONE SIZE'
#  'DLR5 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE S'
#  'DLR6 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE S'
#  'ELL2 S/S CROWNS PRIMARY MOLAR.BOX OF 2 CROWNS ONE SIZE'
#  'ELL4 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE S'
#  'ELL5 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE S'
#  'ELR2 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE S'
#  'ELR4 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE S'
#  'ELR5 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE S'
#  'EUL2 S/S CROWNS PRIMARY MOLAR.BOX OF 2 CROWNS'
#  'EUL6 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE S'
#  'EUR2 S/S CROWNS PRIMARY MOLAR.BOX OF 2 CROWNS ONE SIZE'
#  '1470LK 3M FILTEK Z250XT UNIVER.BOX OF LOCAL KIT'
#  '4868A2 FILTEK ONE SYR BULK.BOX OF 4G SYRINGE'
#  '6LL4 S/S CROWN PERMANENT MOLAR.BOX OF 5 CROWNS ONE SIZE'
#  '6LR2 S/S CROWN PERMANENT MOLAR.BOX OF 5 CROWNS ONE SIZE'
#  '6LR4 S/S CROWN PERMANENT MOLAR.BOX OF 5 CROWNS ONE SIZE'
#  '6UL2 S/S CROWN PERMANENT MOLAR..BOX OF 5 CROWNS ONE SIZ'
#  '6UL5 S/S CROWN PERMANENT MOLAR.BOX OF 5 CROWNS ONE SIZE'
#  '6UR7 S/S CROWN PERMANENT MOLAR.BOX OF 5 CROWNS ONE SIZE'
#  '914001 PEDO STRIP CROWN ULC1.BOX OF 5 CROWNS ONE SIZE'
#  '914002 PEDO STRIP CROWN ULC2.BOX OF 5 CROWNS ONE SIZE'
#  '914011 PEDO STRIP CROWN URC1.BOX OF 5 CROWNS ONE SIZE'
#  '6LL2 S/S CROWN PERMANENT MOLAR.BOX OF 5 CROWNS ONE SIZE'
#  '6LL3 S/S CROWN PERMANENT MOLAR.BOX OF 5 CROWNS ONE SIZE'
#  '6LL5 S/S CR0WN PERMANENT MOLAR.BOX OF 2 CROWNS ONE SIZE'
#  '6LL6 S/S CROWN PERMANENT MOLAR.BOX OF 2 CROWNS ONE SIZE'
#  '6LR3 S/S CROWN PERMANENT MOLAR.BOX OF 2 CROWNS ONE SIZE'
#  '6LR5 S/SCROWN PERMANENT MOLAR.BOX OF 2 CROWNS ONE SIZE'
#  '6LR6 S/S CROWN PERMANENT MOLAR.BOX OF 2 CROWNS ONE SIZE'
#  '6LR7 S/S CROWN PERMANENT MOLAR.BOX OF 2 CROWNS ONE SIZE'
#  '6UL3 S/S CROWN PERMANENT MOLAR.BOX OF 2 CROWNS ONE SIZE'
#  '6UL4 S/S CROWN PERMANENT MOLAR.BOX OF 2 CROWNS ONE SIZE'
#  '6UL6 S/S CROWN PERMANENT MOLAR.BOX OF 2 CROWNS ONE SIZE'
#  '6UL7 S/S CROWN PERMANENT MOLAR.BOX OF 2 CROWNS ONE SIZE'
#  '6UR2 S/S CROWN PERMANENT MOLAR...BOX OF 5 CROWNS OF ONE'
#  '6UR3 S/S CROWN PERMANENT MOLAR.BOX OF 5 CROWN ONE SIZE'
#  '6UR6 S/S CROWN PERMANENT MOLAR.BOX OF 5 CROWNS ONE SIZE'
#  '914004 PEDO STRIP CROWN ULC4.BOX OF 5 CROWNS ONE SIZE'
#  '914021 PEDO STRIP CROWN ULL1.BOX OF 5 CROWNS ONE SIZE'
#  '914022 PEDO STRIP CROWN ULL2.BOX OF 5 CROWNS ONE SIZE'
#  '914024 PEDO STRIP CROWN ULL4.BOX OF 5 CROWNS ONE SIZE'
#  '914031 PEDO STRIP CROWN URL1.BOX OF 5 CROWNS ONE SIZE'
#  '914034 PEDO STRIP CROWN URL4.BOX OF 5 CROWNS ONE SIZE'
#  '7032A3.5 SUP FLOW SYR 2G.SYRINGE OF 2G'
#  '77580 GARANT DISPENSER.BOX OF KIT'
#  '56862 RELYX FIBER POST SIZE 2.PACK OF 10 POSTS SIZE'
#  '56863 RELYX FIBER POST SIZE 3.PACK OF 10 POSTS SIZE'
#  '56865 RELYX FIBER POST DRILL.BOX OF SIZE 2 REFILL'
#  '56866 RELYX FIBER POST DRILL.BOX OF SIZE 3 REFILL'
#  '36972 EXPRESS XT PUTTY SOFT.BOX OF KIT'
#  '71452 GARANT MIXING TIPS YELLO.BOX OF TIPS'
#  '7510 VITREBOND INTRODUCTORY KI.BOX OF KIT'
#  '56920 RELYX ULTIMATE CLICKER.BOX OF 4.5G KIT'
#  '7307 VPS TRAY ADHESIVE.BOTTLE OF 17ML'
#  '5092-I SOF-LEX DIAMOND POLISHI.BOX OF KIT'
#  '56922 RELYX ULTIMATE CLICKER RF A3 OPAQUE.BOX OF 4.5G K'
#  '7032A1 SUP FLOW SYR 2G.SYRINGE OF 2G'
#  '7032B1 SUP FLOW SYR 2G.SYRINGE OF 2G'
#  '41263 SCOTCHBOND UNI ETCHANT.BOX OF KIT'
#  '7018A2D FILTEK Z350XT A2D.SYRINGE OF 4G'
#  '1956 SOF-LEX FINISHING STRIP.PACK OF 120 STRIPS'
#  '4931 SOF-LEX XT DISC KIT 120 D.BOX OF LOCAL KIT'
#  '56660 RELYX TEMP NE.BOX OF KIT'
#  '12248 CLINPRO XT VARNISH.BOX OF 10G KIT'
#  'ND96 S/S CROWNS - PRIMARY MOLA.BOX OF KIT'
#  '56867 RELYX FIBER POST.BOX OF UNIV. DRILL REFILL'
#  '1954 SOF-LEX FINISHING STRIP.PACK OF 150 STRIPS'
#  '71462 INTRA ORAL TIPS.BOX OF TIPS'
#  '12216 CLINPRO TOOTH CREME.BOX OF TOOTHPASTE'
#  '4862A3 BULK FLOW.SYRINGE OF 2G' '56879 RELY X U200 A3.BOX OF KIT'
#  '1470A1 FILTEK Z250XT A1.SYRINGE OF 3G' '7018LK FILTEK Z350XT.BOX OF KIT'
#  '1470A3.5 FILTEK Z250XT.SYRINGE OF 3G'
#  '4862A2 BULK FLOW SYR 2G.SYRINGE OF 2G'
#  '56921 RELYX ULTIMATE CLICKER R.BOX OF 4.5G KIT'
#  '8714TR RELYX VENEER CEMENT REFILL TR'
#  '71450 GARANT MIXING TIPS GREEN.BOX OF TIPS'
#  '31755 IMPREGUM SOFT MED BODY.BOX OF KIT'
#  '7032B2 SUP FLOW SYR 2G, 2 SYR/.2- SYRINGE OF 2G'
#  '71225 PENTA ELASTOMER SYR TIP.PACK OF KIT'
#  '1243A ATTEST CHEM INTEGRAT STM.PACK OF 500 CI'
#  '914014 PEDO STRIP CROWN URC4.BOX OF 5 CROWNS ONE SIZE'
#  '1262 BIOLOGICAL INDICATR:STEAM.BOX OF 100 BI'
#  '55040 3M KETAC FIL PLUS GLASS.BOX OF KIT'
#  '*PEMETREXED DISODIUM (ONTREX).500MG.INJECTION.PACK OF 1'
#  '31796 MONOPHASE SINGLE PK1'
#  '4862A1 BULK FLOW SYR 2G, 2SYR/.2-2G SYRINGES'
#  '7019A2B FILTEK Z350XT A2B CAP.BOTTLE OF 20-0.2G CAPSULE'
#  '7019A3B FILTEK Z350XT A3B CAP.BOTTLE OF 20-0.2G CAPSULE'
#  '36986 3M EXPRESS 2 HEAVY BODY.BOX OF KIT'
#  '4869A2 FILTEK ONE CAP BULK.20 - 0.2G CAPSULES'
#  '7019A3.5B FILTEK Z350XT A3.5B.20.0.2G CAPSULES'
#  '115109 INTERDENTAL BRUSH - L.PACK OF 3 BRUSH'
#  '115083 INTERDENTAL BRUSH - S.PACK OF 3 BRUSH'
#  '71209 ELASTOMER SYRINGE.PACK OF KIT'
#  '4869A1 FILTEK ONE CAP BULK.20 - 0.2G CAPSULES'
#  'DLL2 S/S CROWNS PRIMARY MOLAR 2EA...BOX OF 2 CROWNS ON'
#  'DLL5 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE'
#  'DLL6 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE'
#  'DLL7 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE'
#  'DLR5 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE'
#  'DLR6 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE'
#  'DLR7 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE'
#  'DUR5 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE'
#  'ELL4 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE'
#  'ELL5 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE'
#  'ELL6 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE'
#  'ELR2 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE'
#  'ELR4 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE'
#  'ELR5 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE'
#  'ELR6 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE'
#  'EUL3 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE'
#  'EUL6 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE'
#  'EUR3 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE'
#  'EUR4 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE'
#  'EUR5 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE'
#  '6LR2 S/S CROWN PERMANENT MOLAR.BOX OF 5 CROWNS ONE SIZ'
#  '6LR3 S/S CROWN PERMANENT MOLAR.BOX OF 2 CROWNS ONE SIZ'
#  '6LR4 S/S CROWN PERMANENT MOLAR.BOX OF 5 CROWNS ONE SIZ'
#  'EUL4 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE'
#  'EUL5 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE'
#  'EUR6 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE'
#  '31798 SOFT MONOPHASE SINGLE PK1'
#  '6LL4 S/S CROWN PERMANENT MOLAR.BOX OF 5 CROWNS ONE SIZ'
#  '6LL6 S/S CROWN PERMANENT MOLAR.BOX OF 2 CROWNS ONE SIZ'
#  '6LL7 S/S CROWN PERMANENT MOLAR.BOX OF 5 CROWNS ONE SIZ'
#  '6LR6 S/S CROWN PERMANENT MOLAR.BOX OF 2 CROWNS ONE SIZ'
#  '6UL2 S/S CROWN PERMANENT MOLAR..BOX OF 5 CROWNS ONE SI'
#  '6UL3 S/S CROWN PERMANENT MOLAR.BOX OF 2 CROWNS ONE SIZ'
#  '6UL4 S/S CROWN PERMANENT MOLAR.BOX OF 2 CROWNS ONE SIZ'
#  '6UL5 S/S CROWN PERMANENT MOLAR.BOX OF 5 CROWNS ONE SIZ'
#  '6UL6 S/S CROWN PERMANENT MOLAR.BOX OF 2 CROWNS ONE SIZ'
#  '36974 EXPRESS XT LIGHT WASH.BOX OF KIT'
#  '4931C SOF-LEX 1/2" XT DISC CSE.PACK OF 30 DISCS'
#  '4931M SOF-LEX 1/2 XT DISC MED.BOX OF 30 DISC'
#  '4931SF SOF-LEX 1/2 XT DISC S/F.BOX OF 30 DISC'
#  '6LL2 S/S CROWN PERMANENT MOLAR.BOX OF 5 CROWNS ONE SIZ'
#  '6LR7 S/S CROWN PERMANENT MOLAR.BOX OF 2 CROWNS ONE SIZ'
#  '6UR2 S/S CROWN PERMANENT MOLAR...BOX OF 5 CROWNS OF ON'
#  '61088 KETAC UNIVERSAL AC RF 50.BOX OF - 50'
#  '56816 RELYX UNICEM TRANSLUCENT.BOX OF KITS'
#  '1370A3 FILTEK Z250 A3.SYRINGE OF 4G'
#  '12246L CLINPRO WHITE VARNISH KIT,MELON.BOX OF 100 PACK'
#  '4931F SOF-LEX 1/2 XT DISC FINE.BOX OF 30 DISC'
#  '1370A2 FILTEK Z250 A2.BOX OF 4G SYRINGE'
#  '56944 ASTRINGENT RETRACTION PA.REFILL  PACK OF 25 CAPS'
#  '4868A1 FILTEK ONE SYR BULK 4G...SYRINGE OF 4G'
#  '3M 00135LF BOWIE DICK: TEST PA.CASE OF 30 PACKS'
#  '8100B2 FILTEK P60 B2...BOX OF 4G SYRINGE'
#  '7018A1E FILTEK Z350XT A1E...SYRINGE OF 4G'
#  '7018A3D FILTEK Z350XT A3D...SYRINGE OF 4G'
#  '1322-18MM COMPLY IND TAPE STM.ROLL OF 60YD'
#  'DUL7 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE'
#  'DUL6 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE'
#  'DUR6 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE'
#  '7019A3B FILTEK Z350XT A3B CAP.BOTTLE OF 20-0.2G CAPSUL'
#  'DUR7 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE'
#  '6UR6 S/S CROWN PERMANENT MOLAR.BOX OF 5 CROWNS ONE SIZ'
#  '56861 RELYX FIBER POST SIZE 1 REFILL...10 POST PER SIZ'
#  '7018A1B FILTEK Z350XT A1B' '7018C1B FILTEK Z350XT C1B.SYRINGE OF 4G'
#  '7018C2B FILTEK Z350XT C2B.SYRINGE OF 4G'
#  '56818 RELYX UNICEM APLICAP A2.CAPSULE OF 50'
#  '46956 PROTEMP 4 RF A2.BOX OF KIT' '46957 PROTEMP 4 RF A3.BOX OF KIT'
#  '56922 RELYX ULTIMATE CLICKER RF A3 O'
#  '1470B2 FILTEK Z250XT.BOX OF 3G SYRINGE' '7018A4D FILTEK Z350XT A4D'
#  '7018B1B FILTEK Z350XT B1B.SYRINGE OF 4G'
#  '7018B3B FILTEK Z350XT B3B.SYRINGE OF 4G'
#  '56864 RELYX FIBER POST DRILL S.PACK OF SIZE 1 REFILL'
#  'ELR3 S/S CROWNS PRIMARY MOLAR.BOX OF 2 CROWNS ONE SIZE'
#  '7018B2B FILTEK Z350XT B2B.SYRINGE OF 4G'
#  '6UR7 S/S CROWN PERMANENT MOLAR.BOX OF 5 CROWNS ONE SIZ'
#  '6LL3 S/S CROWN PERMANENT MOLAR.BOX OF 5 CROWNS ONE SIZ'
#  '6LL5 S/S CR0WN PERMANENT MOLAR.BOX OF 2 CROWNS ONE SIZ'
#  '6UL7 S/S CROWN PERMANENT MOLAR.BOX OF 2 CROWNS ONE SIZ'
#  '5090 SOF-LEX PRE-POLISHING SPIRAL...PACK OF 15 SPIRALS'
#  '5091 SOF-LEX DIAMOND PRE-SPIRAL...PACK OF 15 SPIRALS'
#  '77902 PENTAMIX LITE.BOX OF AN EQUIPMENT'
#  '7019A2B FILTEK Z350XT A2B CAP.BOTTLE OF 20-0.2G CAPSUL'
#  '7018C3B FILTEK Z350XT C3B.SYRINGE OF 4G'
#  '1983RA SOF-LEX MANDREL 3/BAG.3 UNIT PER BAG'
#  '7018A2D FILTEK Z350XT A2D...SYRINGE OF 4G'
#  '8100C2 FILTEK P60 C2 4G SYRINGE'
#  '71453 GARANT MIXING TIP BLUE.PACK OF 50 TIPS'
#  '77550 RELYX FIBER POST ELONGAT.PACK OF 10 ELOGATION TIP'
#  '7018AT FILTEK Z350XT AT...SYRINGE OF 4G'
#  '56944 ASTRINGENT RETRACTION PA.REFILL  PACK OF 25 CAPSU'
#  '61089 KETAC UNIVERSAL AC RF 50.BOX OF - 50'
#  '31796 MONOPHASE SINGLE PK1.BOX OF KITS'
#  '1470B1 FILTEK Z250XT.SYRINGE OF 3G'
#  '1470A4 FILTEK Z250XT A4.3G UNI SYR REFILL 1EA/PK'
#  '4930C SOF-LEX 3/8" XT DISC CSE 30.PACK OF 30 DISCS'
#  '4930M SOF-LEX 3/8 XT DISC MED.PACK OF 30 DISC'
#  '7018B1E FILTEK Z350XT B1E.SYRINGE OF 4G'
#  '1370A3 FILTEK Z250 A3, 4G SYRINGE' '1470B3 FILTEK Z250XT B3.SYRINGE'
#  '56861 RELYX FIBER POST SIZE 1 REFILL...10 POST PER SIZE'
#  '7018A1D FILTEK Z350XT A1D.SYRINGE OF 4G'
#  '37470 KETAC CONDITIONER.BOTTLE OF 10ML'
#  '56860 RELYX FIBER POST INTRO.BOX OF KIT'
#  '7018CT FILTEK Z350XT CT...SYRINGE OF 4G'
#  '7614A3T RELYX TRY-IN PASTE SHA.EACH OF SYRINGE'
#  '8714B0.5 RELYX VENEER CEMENT R.EACH OF SYRINGE'
#  '7614A1T RELYX TRY-IN PASTE SHA.EACH OF SYRINGE'
#  '68411 COJET SANDS (3X40G).EACH' '4862U BULK FLOW SYR 2G, 2SYR/KT'
#  '77581 GARANT DISPENSER 4:1/ 10.EACH'
#  '56815 RELYX UNICEM ASSORTED.BOX OF KITS'
#  '7614B0.5T RELYX TRY-IN PASTE S.EACH OF SYRINGE'
#  '41279 SBU GIANT PACK L-POP.SBOX OF 100 L-POP'
#  '46954 PROTEMP 4 RF A1.PACK OF EACH'
#  '8714WO RELYX VENEER CEMENT.SYRINGE OF 3G'
#  '8714A1 RELYX VENEER CEMENT REF.EACH OF SYRINGE'
#  '8714A3 RELYX VENEER CEMENT REF.EACH OF SYRINGE'
#  '46972 PROTEMP 4 RF A3.5.BOX OF KIT' '56877 RELY X U200 TRANSLUCENT'
#  '12646 CLINPRO' '4868A1 FILTEK ONE SYR BULK 4G.SYRINGE OF 4G'
#  '56818 RELYX UNICEM APLICAP A2 50' 'GARANT MIXING TIPS 71450'
#  'DU5 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE SI'
#  '4869 FILTEK ONE CAP BULK.20 - 0.2G CAPSULES'
#  '7019 FILTEK Z350XT 20.0.2G CAPSULES' '56877 RELY X U200'
#  '56816 RELYX UNICEM TRANSLUCENT 50' 'MIXING TIPS 77510 (77919 PENTA)'
#  '56897 RELYX U200 AUTOMIX RF TR' '1470 FILTEK Z250XT SYRINGE OF 3G'
#  '1470 FILTEK Z250XT.SYRINGE OF 3G (A3)'
#  '4869A3 FILTEK ONE CAP BULK 20/BG.BOTTLE OF 20G'
#  '71453 GARANT MIXING TIPS BLUE 50/PK'
#  '800112 CROWN CONTOURING PLIER.EACH OF UNIT'
#  '800417 CROWN CRIMPING PLIER.EACH OF KIT'
#  '1470A1 FILTEK Z250XT SYRINGE OF 3G' '71462 INTRA ORAL TIPS'
#  '1370 FILTEK Z250 BOX OF 4G SYRINGE'
#  '4868 FILTEK ONE SYR BULK 4G.SYRINGE OF 4G'
#  'DLL S/S CROWNS PRIMARY MOLAR.BOX OF 2 CROWNS ONE SIZE'
#  '1470C2 FILTEK Z250XT C2.3G UNI SYR REFILL 1EA/PK'
#  '1370A2 FILTEK Z250 BOX OF 4G SYRINGE'
#  '12646 CLINPRO FISSURE SEALANT KIT' '73040 APLICAP ACTIVATOR...ACTIVATOR'
#  '6UL7 S/S CROWN PERMANENT MOLAR.BOX OF 5 CROWNS ONE SIZE'
#  '6LR5 S/SCROWN PERMANENT MOLAR.BOX OF 5 CROWNS ONE SIZE'
#  '56817 RELYX UNICEM APLICAP A3 X 50'
#  '56895 RELYX U200 AUTOMIX RF A2.BOX OF KIT'
#  '56896 RELYX U200 AUTOMIX - SYRINGE SHADE A3 OPAQUE   BO'
#  '7614TRT RELYX TRY-IN PASTE SHA.EACH OF SYRINGE'
#  '76973 ELIPAR DEEPCURE-L 100V -.EACH OF UNIT'
#  '8714TR RELYX VENEER CEMENT REFILL SHADE TRANSLUCENT'
#  'PEROZIN CREAM.TUBE OF 100ML'
#  '3700T FILTEK TIPS 20G 20 19-GAUGE DISPENSING TIPS...EAC'
#  '3740T FILTEK BULK FILL TIPS 20.DISPENSING TIPS.EACH OF'
#  '56950 FIBER POST 3D REFILL SIZE 2 RED'
#  '56951 FIBER POST 3D REFILL SIZE 3 BLUE'
#  '6UL4 S/S CROWN PERMANENT MOLAR.BOX OF 5 CROWNS ONE SIZE'
#  '6UL6 S/S CROWN PERMANENT MOLAR.BOX OF 5 CROWNS ONE SIZE'
#  '7614WOT RELYX TRY-IN PASTE SHA.EACH OF SYRINGE'
#  '77550 RELYX FIBER POST ELONGATION TIP'
#  '56949 FIBER POST 3D REFILL SIZE 1 YELLOW'
#  '56914 RELYX U200 AUTOMIX.PACK OF 1 UNIT'
#  '56957 FIBER POST 3D INTRO KIT.BOX OF KIT'
#  '6LR7 S/S CROWN PERMANENT MOLAR.BOX OF 5 CROWNS ONE SIZE'
#  '7032B2 SUP FLOW SYR 2G.BOX OF 1 KIT'
#  'SFN10 NAIL MYCOSIS.PACK OF 2 TUBES'
#  '4869B1 FILTEK ONE CAP BULK 20/.EACH OF BAG'
#  '7019A3.5B FILTEK Z350XT 20.0.2G CAPSULES'
#  '73050 APLICAP APPLIER.EACH OF KIT' 'ELL5 S/S CROWNS PRIMARY MOLAR 2/BOX'
#  '76301 ROTOMIX 230V GB.EACH OF UNIT'
#  '7423 SCOTCHBOND ETCHANT 9ML VIAL  1/EACH'
#  'BABY NADIF NASAL SPRAY.HYPERTONIC.BOTTLE OF 50ML'
#  '36975 EXPRESS XT REGULAR/MEDIUM BODY REFILL.BOX OF KIT'
#  '6LL5 S/S CR0WN PERMANENT MOLAR.BOX OF 5 CROWNS ONE SIZE'
#  '41263 SCOTCHBOND UNIVERSAL ETCHANT RF EE'
#  'ELL6 S/S CROWNS PRIMARY MOLAR 2/BOX'
#  '12647 CLINPRO SEALANT SYRINGE.PACK OF SYRINGE'
#  '7018A3B FILTEK Z350XT.SYRI' '56879 RELY X U200 A3.BOX O'
#  '4931SF SOF-LEX 1/2 XT DISC S/F.PACK OF 30 DISC'
#  'EUR6 S/S CROWNS PRIMARY MO' 'DUL7 S/S CROWNS PRIMARY MO'
#  'DUR6 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE SIZE'
#  'EUL6 S/S CROWNS PRIMARY MO' 'DLL5 S/S CROWNS PRIMARY MO'
#  'DUL5 S/S CROWNS PRIMARY MOLAR 2EA..BOX OF 2 CROWNS ONE SIZE'
#  'EUL5 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE SIZE'
#  'ELL5 S/S CROWNS PRIMARY MO' 'DLR5 S/S CROWNS PRIMARY MO'
#  '56878 RELY X U200 A2.BOX O'
#  'ELR2 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE SIZE'
#  'ELL6 S/S CROWNS PRIMARY MO' '3525A RELYX LUTING 2 CLICK'
#  'EUR7 S/S CROWNS PRIMARY MO' 'EUL7 S/S CROWNS PRIMARY MO'
#  'EUR4 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE SIZE'
#  'DLL6 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE SIZE'
#  'EUR5 S/S CROWNS PRIMARY MO' '46957 PROTEMP 4 RF A3.BOX'
#  'DENTAL STONE TYPE 3 (GREEN) PACK OF 5KG' '914001 PEDO STRIP CROWN UL'
#  '56920 RELYX ULTIMATE CLICK'
#  'ELR4 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE SIZE'
#  'DLL7 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE SIZE'
#  'DUL4 S/S CROWNS PRIMARY MO' 'DUR7 S/S CROWNS PRIMARY MO'
#  'ELR6 S/S CROWNS PRIMARY MO' 'ND96 S/S CROWNS - PRIMARY'
#  'ELR7 S/S CROWNS PRIMARY MO'
#  'DLR7 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE SIZE'
#  'ELL7 S/S CROWNS PRIMARY MO' 'ELR5 S/S CROWNS PRIMARY MO'
#  '56817 RELYX UNICEM APLICAP' '914023 PEDO STRIP CROWN UL'
#  '56897 RELYX U200 AUTOMIX RF TR.BOX OF 1 KIT' '1370A2 FILTEK Z250 BOX OF'
#  '915100 PEDO STRIP CROWNS K' 'DUR4 S/S CROWNS PRIMARY MO'
#  'DUL6 S/S CROWNS PRIMARY MO'
#  'ELL4 S/S CROWNS PRIMARY MOLAR 2EA.BOX OF 2 CROWNS ONE SIZE'
#  'DENTAL PLASTER OF PARIS PACK OF 10KG'
#  'EUR6 S/S CROWNS PRIMARY MOLAR.BOX OF 2 CROWNS ONE SIZE'
#  '4868B1 FILTEK ONE SYR BULK 4G.EACH OF BAG'
#  'GENGIGEL TEETHING GEL.TUBE OF 20ML' 'IMINOX TABLET 100MG.PACK OF 6 X10S'
#  '56923 RELYX ULTIMATE CLICKER R.EACH OF UNIT'
#  'SFN10 NAIL MYCOSIS 3.3ML SOLUTION'
#  '36891 EXPRESS XT PENTA HB...EACH OF UNIT'
#  'A0409225G0103 PROTAPER GOLD ASST 25MM...6 PCS/BLISTER'
#  'A12MA02101012 K-FILE M-ACCESS 21MM 010...6 PCS / PACK'
#  '60667350 PRIME AND BOND UNIVERSAL...4ML'
#  '60603045 SDR PLUS SYRINGE ECO REFILL...10 SYRINGES X 1'
#  'A0409221G0103 PROTAPER GOLD ASST 21MM...6 PCS/BLISTER'
#  '61116001 KALZINOL LIQUID 15 ML (15 ML/BOTTLE)...15 ML/B'
#  'BSTW1GG321015 WAVEONE GOLD GLIDER 21MM...3 FILES'
#  'A012X02100604 C%2BFILE READYSTEEL 21MM 006...6 PCS/BOX'
#  'BSTW1GG325015 WAVEONE GOLD GLIDER 25MM...3 FILES'
#  '610007 IRMCOMB PKGIVORY 40GRAMPWDR%2B15MLLQUID...40 GM'
#  'A12MA02101512 K-FILE M-ACCESS 21MM 015...6 PCS / PACK'
#  'A12MA02100812 K-FILE M-ACCESS 21MM 008...6 PCS / PACK'
#  'A0756221G0P03 WVENE GLD PRMRY 6-FILE STER 21MM...6 PCS/'
#  '61116100 KALZINOL POWDER 40 G (40 GRAM/BOTTLE)...40 GRA'
#  'A12MA02501512 K-FILE M-ACCESS 25MM 015...6 PCS / PACK'
#  'A0756225G0P03 WVENE GLD PRMRY 6-FILE STER 25MM...6 PCS/'
#  'A175W00000S03 WAVEONE GOLD PPR POINT STERILE SMALL...18'
#  'A12MA02100612 K-FILE M-ACCESS 21MM 006...6 PCS / PACK'
#  'C060100000100 EASYPOST PRECISION DRILL 1...3 PCS'
#  'A241W00000303 PROTAPER GOLD PAPER POINTS F3...180PCS/ B'
#  'A16MA02502512 HEDSTROEM M-ACCESS 25MM 025...6 PCS / PAC'
#  'B00PNGPF000X3 PROTAPER NEXT CONFORM FIT?  X3...60 PCS'
#  'A241W00000103 PROTAPER GOLD PAPER POINTS F1...180PCS/ B'
#  'A241W00000203 PROTAPER GOLD PAPER POINTS F2...180PCS/ B'
#  '41282 SINGLE BOND UNIVERSAL 5ML'
#  '41263 SCOTCHBOND UNIVERSAL.ETCHANT BOX OF KIT'
#  'BSTPULH6250SL PROTPR ULTMT HND USE SLDR 25 MMX6...6 FIL'
#  '12646 CLINPRO SEALANT INTRO.BOX OF LOCAL KIT'
#  '7018LK FILTEK Z350XT UNIVERSAL.RESTORATIVE INTRO KIT'
#  '778217V DS 50 ML RED MIX TIP - 40 COUNT...40 PCS'
#  '4862A3 FILTEK BULK FILL FLOW.RESTORATIVE (SYRINGE) 2SYR'
#  'BSTPULH6210SH PROTPR ULTMT HND USE SHPR 21 MM X6...6 FI'
#  'A092322500103 PROGLIDER 3FILE STERILE 25MM...3 STERILE'
#  '623451Y DYCAL DEN STD EXPORT...13 GM BASE%2B11 GM CTLYS'
#  'BSTPULH6210F1 PROTAPR ULTMTE HND USE F1 21 MM X6...6 FI'
#  '7423 SCOTCHBOND ETCHANT GEL.VIAL 9ML BOTTLE'
#  'BSTPULH6210F2 PROTAPR ULTMTE HND USE F2 21 MM X6...6 FI'
#  '51202 ADPER SINGLE BOND 2 VIAL 6G'
#  'BSTPULH6250F1 PROTAPR ULTIMTE HND USE F1 25 MM X6...6 F'
#  'BSTPULH6250SH PROTAPR ULTIMTE HND USE SHPR 25MMX6...6 F'
#  '4862A2 FILTEK BULK FILL FLOW.RESTORATIVE (SYRINGE) 2SYR']
#
#
# Unique values in 'state':
# ['SELANGOR' 'PAHANG' 'PERAK' 'TERENGGANU' 'NEGERI SEMBILAN' 'JOHOR'
#  'PULAU PINANG' 'MELAKA' 'WP(KL)' 'SARAWAK' 'SABAH' 'KEDAH' 'KELANTAN'
#  'PERLIS' 'WP(PUTRAJAYA)' 'LABUAN' 'WILAYAH PERSEKUTUAN' 'WP LABUAN'
#  'WP PUTRAJAYA' 'KUALA LUMPUR' 'WILAYAH PERSEKUTUAN KUALA LUMPUR'
#  'WILAYAH PERSEKUTUAN LABUAN' 'WILAYAH PERSEKUTUAN PUTRAJAYA' 'WP(IKN)'
#  'WP KL']

# %%
import re

# Function to extract and format product details as a single string
def extract_product_details(desc):
    # Convert to uppercase for uniformity
    desc = desc.upper()

    # Extract size information (e.g., 150ML, 20G, PACK OF 3)
    size_match = re.search(r'\d+\s*(ML|G|MG|L|PACK|TUBE|BOX|PCS)', desc)
    size = size_match.group(0) if size_match else "NO SIZE"

    # Extract product type based on common keywords
    if "GEL" in desc:
        product_type = "GEL"
    elif "MOUTHWASH" in desc or "MOUTHRINSE" in desc:
        product_type = "MOUTHWASH"
    elif "TOOTHPASTE" in desc or "DENTAL CREAM" in desc:
        product_type = "TOOTHPASTE"
    elif "BRUSH" in desc:
        product_type = "BRUSH"
    elif "PLASTER" in desc or "STONE" in desc:
        product_type = "DENTAL PLASTER"
    elif "PACK" in desc:
        product_type = "PACK"
    elif "CROWN" in desc:
        product_type = "CROWN"
    elif "BOTTLE" in desc:
        product_type = "BOTTLE"
    elif "KIT" in desc:
        product_type = "KIT"
    elif "SYRINGE" in desc:
        product_type = "SYRINGE"
    else:
        product_type = "OTHER"

    # Extract product name (everything before the first period or size keyword)
    product_name_match = re.split(r'\.|(\d+\s*ML|\d+\s*G|\d+\s*PACK)', desc)
    product_name = product_name_match[0].strip() if product_name_match else "UNKNOWN"

    #extract size - corrected regex
    size_match=re.search(r'\d+(\s*(ML|G|MG|L|PACK|TUBE|BOX|PCS))', desc)
    size=size_match.group(0) if size_match else "UNKNOWN"

    # Combine the extracted details into a single string
    combined_details = f"{product_name} ({product_type}, {size})"
    return combined_details

# Apply the function to the Description column
df['description'] = df['description'].fillna('UNKNOWN').apply(extract_product_details)
print(df['description'].head())
# Out:
# 0               AFTAMED GEL CLASSIC (GEL, 8ML)
# 1                AFTAMED JUNIOR GEL (GEL, 8ML)
# 2                     GENGIGEL GEL (GEL, 20ML)
# 3                     GENGIGEL GEL (GEL, 20ML)
# 4    GENGIGEL HYDROGEL MOUTHRINSE (GEL, 150ML)
# Name: description, dtype: object

# %%
#Standardise cust_group
def standardize_cust_group(value):
    value = str(value).strip().title()  # Remove extra spaces and convert to title case
    mapping = {
        "(D) Private": "Private",
        "(C) Institution": "Institution",
        "(A) Moh Sales": "MOH Sales",
        "Unidentified": "Unidentified"
    }
    return mapping.get(value, value)  # Replace if in mapping, otherwise keep original

# Apply standardization
df['cust_group'] = df['cust_group'].fillna('Unknown').apply(standardize_cust_group)

#filter out row where cust_group is "Unidentified"
df = df[df['cust_group'] != 'Unidentified']

# Check unique values
print(df['cust_group'].unique())
# Out:
# ['Private' 'Institution' 'MOH Sales']

# %%
def standardize_month(value):
    value = str(value).strip().capitalize()  # Remove spaces and capitalize
    valid_months = [
        "January", "February", "March", "April", "May", "June",
        "July", "August", "September", "October", "November", "December"
    ]
    return value if value in valid_months else "Unknown"

# Apply standardization
df['month'] = df['month'].fillna('Unknown').apply(standardize_month)

# Check unique values
print(df['month'].unique())
# Out:
# ['January' 'February' 'March' 'April' 'May' 'June' 'July' 'August'
#  'September' 'October' 'November' 'December']

# %%
def standardize_brand(value):
    return str(value).strip().title()  # Remove spaces and convert to title case

# Apply standardization
df['brand'] = df['brand'].fillna('Unknown').apply(standardize_brand)

# Check unique values
print(df['brand'].unique())
# Out:
# ['Aftamed' 'Gengigel' 'V-Hyal' 'Sfn10' 'Atopshield' 'Allerstop' '3M'
#  'Ontrex' 'Perozin' 'Baby Nadif' 'Dental Stone' 'Dental Plaster' 'Iminox'
#  'Dentsply']

# %%
def standardize_state(value):
    value = str(value).strip().title()  # Remove extra spaces and capitalize each word
    # Mapping variations to standardized names
    mapping = {
        "Selangor": "Selangor",
        "Pahang": "Pahang",
        "Perak": "Perak",
        "Terengganu": "Terengganu",
        "Negeri Sembilan": "Negeri Sembilan",
        "Johor": "Johor",
        "Pulau Pinang": "Pulau Pinang",
        "Melaka": "Melaka",
        "Wp(Kl)": "Wilayah Persekutuan Kuala Lumpur",
        "Wp Kl": "Wilayah Persekutuan Kuala Lumpur",
        "Kuala Lumpur": "Wilayah Persekutuan Kuala Lumpur",
        "Wilayah Persekutuan Kuala Lumpur": "Wilayah Persekutuan Kuala Lumpur",
        "Wilayah Persekutuan": "Wilayah Persekutuan Kuala Lumpur",
        "Wp Labuan": "Wilayah Persekutuan Labuan",
        "Wilayah Persekutuan Labuan": "Wilayah Persekutuan Labuan",
        "Wp(Putrajaya)": "Wilayah Persekutuan Putrajaya",
        "Wp Putrajaya": "Wilayah Persekutuan Putrajaya",
        "Wilayah Persekutuan Putrajaya": "Wilayah Persekutuan Putrajaya",
        "Wp(Ikn)": "Wilayah Persekutuan Kuala Lumpur",
        "Labuan": "Wilayah Persekutuan Labuan",
        "Unknown" : "Unknown"
        # Add more mappings as needed
    }
    return mapping.get(value, value)  # Replace if in mapping, otherwise keep original

# Apply standardization
df['state'] = df['state'].fillna('Unknown').apply(standardize_state)

# Check unique values
print(df['state'].unique())
# Out:
# ['Selangor' 'Pahang' 'Perak' 'Terengganu' 'Negeri Sembilan' 'Johor'
#  'Pulau Pinang' 'Melaka' 'Wilayah Persekutuan Kuala Lumpur' 'Sarawak'
#  'Sabah' 'Kedah' 'Kelantan' 'Perlis' 'Wilayah Persekutuan Putrajaya'
#  'Wilayah Persekutuan Labuan']

# %%
#columns changed to categorical data
categorical_columns = ['cust_group', 'month', 'brand', 'sector', 'state']
for col in categorical_columns:
    df[col] = df[col].astype('category')
# to verify the changes
print("Updated Column Data Types:")
print(df.dtypes)
# Out:
# Updated Column Data Types:
# cust_group            category
# month                 category
# year                     int64
# brand                 category
# description             object
# sector                category
# quantity               float64
# total_sales            float64
# state                 category
# total_sales_capped     float64
# quantity_capped        float64
# log_total_sales        float64
# dtype: object

# %% [markdown]
# # **RESULTS AND DISCUSSION**

# %% [markdown]
# 1. Monthly sales trend

# %%
#Plot the sales trend over months by year
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter


def rm_formatter(x, pos):
    return f"RM{int(x):,}"


plt.figure(figsize=(12, 6))
#custom_palette
custom_palette={
    2021: '#1f77b4',
    2022: '#9467bd',
    2023: '#ffdd44',
    2024: '#ff7f0e'
}
#apply custom colors
sns.lineplot(data=df, x='month', y='total_sales', hue='year', marker='o', estimator='sum', linewidth=2,)
#customise the plot
plt.title('Sales Trend Over Months by Year', fontsize=16, fontweight='bold')
plt.xlabel('Month', fontsize=12)
plt.ylabel('Total Sales (in RM)', fontsize=12)
plt.gca().yaxis.set_major_formatter(FuncFormatter(rm_formatter))
plt.legend(title='Year')
plt.grid(color='gray', linestyle='--', linewidth=0.5)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# The graph shows the sales increasing over the months across different years from 2021 to 2024. Sales in 2024 are generally higher compared to previous years showing a steady growth over the years. The lines for different years follow a similar general shape but with variation in magnitude and it shows seasonal patterns as there are months showing higher value while some dip significantly, for example in June 2022. The significant dip could be attributed to lower demand during that period.
#
# The upward trend in 2024 suggests increase market demand and effective marketing strategies. The company can plan marketing strategies according to the peak months for example plan for promotions during the peak months and stabilize sales during low peak months by conducting targeted marketing campaigns. These data can be used to aid in decision-making and forecast future sales trends

# %% [markdown]
# 2. Top 10 products by sales

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import seaborn as sns  # Import seaborn for color palettes


def rm_formatter(x, pos):
    return f"RM{int(x):,}"

top_products = df.groupby('description')['total_sales'].sum().sort_values(ascending=False).head(10)
plt.figure(figsize=(10, 6))

# Get a list of colors from a seaborn palette
colors = sns.color_palette("hls", len(top_products))

# Pass the list of colors to the 'color' argument
top_products.plot(kind='bar', color=colors)

plt.title('Top 10 Products by Sales')
plt.xlabel('Product')
plt.ylabel('Total Sales (in RM)')
plt.xticks(rotation=45, ha='right')

# Apply the rm_formatter to the y-axis
plt.gca().yaxis.set_major_formatter(FuncFormatter(rm_formatter))

plt.tight_layout()
plt.show()

# %% [markdown]
# The bar chart above shows the top 10 products by sales in Novel Department at Pharmaniaga where the products can be seen represents various kind of formulations such as spray, gel and sachets even for the same brand for example, Gengigel. The top product is Aftamed Spray bottle of 20ml as it shows a significantly larger sales volume of 10 million compared to other products. Aftamed spray bottle of 20ml seems to be high priority item in terms of sales distribution and vital for the company to ensure its availabiltiy ofor the businesss. However, there is a significant drop of sales between the top product and the second top product, Gengigel spray bottle of 20ml and a more gradual decline among the rest. These suggests these products need targeted marketing or promotions to boost its sales as there are opprotunity for growth. Based on this graph, it also suggests customer preference towards formulations like spray and gel hence future investment on similar product formulation may bring profit. The company can implement cross selling strategies by bundling top product with lower-ranked products to boost sales. According to a study  [Cross-Selling]( https://www.researchgate.net/publication/242537131_Cross-Selling_Sequentially_Ordered_Products_An_Application_To_Consumer_Banking_Services)  on "Cross-Selling Sequentially Ordered Products: An Application To Consumer Banking Services", customers have predictable lifecycles which provides opportunities for businesses to cross-sell additional products and services to existing customers

# %% [markdown]
# 3. Pareto Analysis

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter


def rm_formatter(x, pos):
    return f"RM{int(x):,}"


pareto_data = df.groupby('brand', observed=False)['total_sales'].sum().sort_values(ascending=False)
pareto_cumulative = pareto_data.cumsum() / pareto_data.sum() * 100

# Increased figure size, especially the width
plt.figure(figsize=(18, 8))
plt.bar(pareto_data.index, pareto_data.values, color=plt.cm.Paired.colors)
plt.xlabel('Brand', fontsize=12)
plt.ylabel('Total Sales (in RM)', fontsize=12)
plt.gca().yaxis.set_major_formatter(FuncFormatter(rm_formatter))
plt.title('Pareto Analysis of Total Sales by Brand', fontsize=14)
plt.twinx()
plt.plot(pareto_cumulative, marker='o', linestyle='-', color='red')
plt.axhline(80, color='black', linestyle='--', label="80% Threshold")
plt.ylabel('Cumulative Percentage')
plt.legend(loc='upper right')
# Get unique brand names from pareto_data index
brands = pareto_data.index
# Use brands for x-axis ticks and labels, set rotation to vertical and reduced fontsize
plt.xticks(range(len(brands)), labels=brands, rotation='vertical', ha='right', fontsize=8)
# Adjust subplot parameters to add more space for x-axis labels
plt.subplots_adjust(bottom=0.35)  # Increased bottom margin for more space

plt.tight_layout()
plt.show()

# %% [markdown]
# The Pareto Chart above, also known as the 80/20 rule chart helps to identify the key brand products that contirbute to the overall sales. The left y-axis represent the total sales of each brand in RM and arranged in descending order whereas the righ y-axis shows the cumulative precentage of total sales. The black dashed line on the chart represents the 80% threshold of cumulative sales. The intersection point between the dashed line and the red curve indicates which brand contibuting to 80% of total sales.
#
# Based on the chart, Gengigel and Aftamed are the brand products that contribute to 80% of total sales whereas the other brands represented by smaller bars to the right contibute minimally. The business should focus on the key brand contibutors in terms of inventory managment and promotional events. Performance of the low performing brands should be further evaluated before further actions taken, for example exploration of different strategies to improve the sales or for discontinuation of product if necessary

# %% [markdown]
# 4. Percentage growth of sales year over year

# %% [markdown]
# As mentioned previously in the handling outliers part,  the data has outliers which is handled differently in this analysis. Outliers can distort percentage of growth analysis by causing extreme spikes hence the outliers are capped using the IQR method to smooth the trend. The analysis is performed with and without capping for comparison

# %%
Q1 = df[['total_sales', 'quantity']].quantile(0.25)
Q3 = df[['total_sales', 'quantity']].quantile(0.75)
IQR = Q3 - Q1
upper_fence = Q3 + 1.5 * IQR
lower_fence = Q1 - 1.5 * IQR

# Capping values for smoother trends (e.g., 95th percentile)
upper_cap = df['total_sales'].quantile(0.95)
df['Capped Sales'] = df['total_sales'].clip(upper=upper_cap)

# Calculate Year-over-Year percentage growth
# Creating a DataFrame with the necessary columns
yearly_growth = df.groupby('year').agg(
    Total_Sales=('total_sales', 'sum'),  # Aggregating 'total_sales'
    Capped_Sales=('Capped Sales', 'sum') # Aggregating 'Capped Sales'
).reset_index()

# Calculate percentage change
yearly_growth['Pct_Change_Original'] = yearly_growth['Total_Sales'].pct_change() * 100
yearly_growth['Pct_Change_Capped'] = yearly_growth['Capped_Sales'].pct_change() * 100


# Bar plot for Year-over-Year Sales Growth
plt.figure(figsize=(10, 6))
bar_width = 0.35
x = range(len(yearly_growth['year']))

# Original growth
plt.bar(x, yearly_growth['Pct_Change_Original'], bar_width, label='Original Growth')

# Capped growth
plt.bar([i + bar_width for i in x], yearly_growth['Pct_Change_Capped'], bar_width, label='Capped Growth')

plt.title('Year-over-Year Sales Growth (Original vs. Capped)', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Percentage Growth (%)', fontsize=12)
plt.xticks([i + bar_width / 2 for i in x], yearly_growth['year'])
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# The chart above displays the sales growth rate for year 2022, 2023 and 2024 where original growth represents sales growth based on the original data with outliers wheres capped growth in orange represents sales growth after capping outliers. Capped growth is included to represent a fair representation of growth trend without the presence of outliers that may skew the results and more reliable for forecasting. The original growth provides full transparency showing the impact of extreme contributorsto the overall sales growth performance. However, there is minimal difference bwtween the capped and original growth hence we can focus on the results based on original growth for clarity and simplicity.
#
# In 2022, the bar shows a positive growth rate of about 28%. Sales continue to grow in 2023 showing a growth rate of 30%, however the sales growth is lower in 2024, about 10%. Overall, sales been growing steadily but at a slower rate. The Covid-19 pandemic could have influenced the growth rate along with other factors such as logistic issues, lower marketing investments and business focus on only sustaining existing customers. The research paper ["COVID-19 affect logistics and supply chain processes"](https://pmc.ncbi.nlm.nih.gov/articles/PMC10199754/) provides empirical evidence on the impact of the Covid-19 pandemic on logistics and supply chain processes which affects various sector of business.

# %% [markdown]
# 4. Sales Distribution by Customer Group

# %%
customer_group_sales = df.groupby('cust_group', observed=False)['total_sales'].sum()

plt.figure(figsize=(8, 5))
customer_group_sales.plot(kind='pie', autopct='%1.1f%%', startangle=140, colors=sns.color_palette("pastel"))
plt.title('Sales Distribution by Customer Group')
plt.ylabel('')
plt.show()

# %% [markdown]
# The pie chart on "Sales Distribution by Customer Groups" shows that the majority of sales of 86.8% comes from private customers.Hence, the private group of customers are the primary source of revenue for the business in Novel Department. This gorup of customers can be expanded for future plan. The next portion of sales of 9.4% comes from Institution. There could be opportunities for sales growth by focusing on partnerships with institutions. Ministry of Health(MOH) contibutes to a small fraction of 3.8% of the total sales. This could be due to a niche market or limited contracts.

# %% [markdown]
# 5. Heatmap of Sales Distribution Across Region

# %%
region_sales = df.pivot_table(values='total_sales', index='state', columns='year', aggfunc='sum', fill_value=0, observed=False)
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

plt.figure(figsize=(10, 6))
sns.heatmap(region_sales, annot=True, fmt=".0f", cmap="YlGnBu")
plt.title('Heatmap of Sales Distribution Across Regions')
plt.show()

# %% [markdown]
# The heatmap above shows the sales distribution across various regions from 2021 till 2024. The darker shade and high sales value in the heatmap shows Selangor is the key sales region consistently. States like Johor, Perak, Penang and Wilayah Persekutuan Kuala Lumpur shows increasing growth over the years. Smaller regions like Perlis shows a relatively slow and stable growth. The drop in sales in Wilayah Persekutuan Putrajaya can be investigated as the drop could be due to reasons like demographic changes or reduced business activity.

# %% [markdown]
# 6. Stacked Comparison of Cost vs Revenue Across Categories

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

category_data = df.groupby('brand', observed=False)[['total_sales', 'quantity']].sum()

category_data.plot(kind='bar', stacked=True, figsize=(10, 6), color=['coral', 'dodgerblue'], alpha=0.8)
plt.title('Comparison of Sales vs Quantity by Brand')
plt.ylabel('Total Value (Log Scale)')
plt.legend(['Sales', 'Quantity'])
plt.yscale('log')
plt.show()

# %% [markdown]
# The graph highlights the relationship between quantity sold and revenue generated across different brands. Gengigel is the high revenue driver for the business and provides opportunities for futher expansion in market. Next is Aftamed that also shows a storng market presence. Other brands like V-Hyal, Sfn10, and Atopshield shows potential. Based on the insgihts obtained, there are several points for consideration such as awareness for brandds that are low-performing, saturation of market which can limit the hrowth of some products and also the pricing of the products for further improvement. Understanding of customer needs are also crucial as mentioned in an article "Value-based pricing involves setting prices based on a consumer's perceived value of a product or service", which mentioned for companies to develop a successful value-based pricing strategy, they must invest a significant amount of time with their customers to determine their wants [Biomenthal,2024](https://www.investopedia.com/terms/v/valuebasedpricing.asp).

# %% [markdown]
# # **CONCLUSION**

# %% [markdown]
# In conclusion, the analysis conducted shows there are seasonal trends implicating promotional planning to maximise sales during the peak season. The pareto analysis highlights a small group of products, Gengigel and Aftamed contribute to majority of sales implicating the importance to expand the top performing product lines to drive business growth. Private customers are the major contributors to sales whereas other customer groups has potential to grow. The company should strengthen their relationship with private sector customer while develop strategies to boost sales among other customer groups. Market research required to identify barriers in underperforming regions while replicationg strategies from region like Selangor. Costing in low margin products should be addressed and reevaluated for profitability.
